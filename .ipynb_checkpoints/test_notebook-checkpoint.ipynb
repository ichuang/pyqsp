# %%
import pyqsp
from pyqsp.LPoly import *
from pyqsp.gadgets import *
import jax
import jax.numpy as jnp
import numpy as np
from tqdm.notebook import tqdm
from scipy.interpolate import approximate_taylor_polynomial
from matplotlib import pyplot as plt
import copy

np.set_printoptions(linewidth=100000)

# %%
# Defines two atomic gadget

Xi_1 = [np.array([0, np.pi/3, -np.pi/3, 0])]
S_1 = [[0, 1, 0]]
G = AtomicGadget(Xi_1, S_1, label="G")

Xi_2 = np.array([[np.pi/5, np.pi/6, np.pi/6, -np.pi/4]])
S_2 = [[1, 0, 1]]
G_tilde = AtomicGadget(Xi_2, S_2, label="G_tilde")

# %%
# Performs an interlink of the G gadget with the extraction gadget. Note that deg is the 
# degree of the polynomial used in the correction. If it were instead "None" no correction
# would be applied
deg = 20

G_interlink = G.interlink(G_tilde, [
    (('G', 0), ('G_tilde', 0), deg)
])

# %%
AdditionGadget("G_add").get_qsp_unitary(("G_add", 0))({("G_add", 0): 0.3, ("G_add", 1):0.1})
# Out:
# array([[ 0.6328    +1.72957168e-16j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.66435562+3.97738311e-01j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.6328    +1.72957168e-16j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.66435562+3.97738311e-01j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.6328    +1.72957168e-16j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.66435562+3.97738311e-01j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.6328    +1.72957168e-16j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.66435562+3.97738311e-01j],
#        [-0.66435562+3.97738311e-01j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.6328    -1.89216008e-16j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j, -0.66435562+3.97738311e-01j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.6328    -1.89216008e-16j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j, -0.66435562+3.97738311e-01j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.6328    -1.66533454e-16j,  0.        +0.00000000e+00j],
#        [ 0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j, -0.66435562+3.97738311e-01j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.        +0.00000000e+00j,  0.6328    -1.66533454e-16j]])

# %%
# Fourth Chebyshev polynomial
T_4 = lambda x : 8 * (x ** 4) - 8 * (x ** 2) + 1
T4_composite = lambda x, y: 0.5 * (T_4(x) + T_4(y))

# %%
# Tests the addition gadget
fn = lambda x, y : AdditionGadget("G_add").get_qsp_unitary(("G_add", 0))({("G_add", 0): x, ("G_add", 1):y})[0][0]
data = [[fn(x, y) for x in np.linspace(-1, 1, 200)] for y in tqdm(np.linspace(-1, 1, 200))]
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
plt.matshow(np.real(data))

# %%
plt.matshow([[T4_composite(x, y) for x in np.linspace(-1, 1, 200)] for y in tqdm(np.linspace(-1, 1, 200))])
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
# Tests the fourth root gadget
G_fourth = FourthRootGadget(40, 0.06, 'G_fourth')
X, Y = G_fourth.get_response()
plt.plot(X, Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 # Tests the fourth root gadget
# ----> 2 X, Y = G_sqrt.get_response()
#       3 plt.plot(X, Y)
#
# NameError: name 'G_sqrt' is not defined

# %%
print("In legs = {}".format(G_interlink.in_labels))
print("Out legs = {}".format(G_interlink.out_labels))
# Out:
# In legs = [('G', 0), ('G', 1), ('G_tilde', 1)]
# Out legs = [('G_tilde', 0)]

# %%
# Sets gadget leg inputs
F = lambda x, y : {("G", 0): x, ("G", 1): y, ("G_tilde", 1): 0.5}

# %%
# Gets the sequence of a leg of the gadget interlink
fn = lambda x, y : G_interlink.get_qsp_unitary(('G_tilde', 0))(F(x, y))[0][0]

# %%
# Plots the gadget interlink
data = [[fn(x, y) for x in np.linspace(-1, 1, 20)] for y in tqdm(np.linspace(-1, 1, 20))]
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
plt.matshow(np.real(data))
plt.colorbar()

# %%
# Performs tests of the extraction and sqrt gadgets
G_extraction = ExtractionGadget(29, 'G_ext')
G_sqrt = SqrtGadget(40, 0.06, 'G_sqrt')

# %%
# Plots the response function of the extraction gadget
X, Y = G_extraction.get_response()
plt.plot(X, Y)

# %%
# Gets the response function of the sqrt gadget
X, Y = G_sqrt.get_response()
plt.plot(X, Y)

# %%
# Performs test which interlinks an inverse Chebyshev gadget with the second Chebyshev polynomial

G_cubic = AtomicGadget([[0, np.pi/4, -np.pi/4, 0]], [[0, 0, 0]], label="G_cubic")
G_cheb = AtomicGadget([[0, 0, 0]], [[0, 0]], label="G_cheb")

G_id_1 = G_cubic.interlink(G_sqrt, [
    (('G_cubic', 0), ('G_sqrt', 0), None)
])

G_id_2 = G_id_1.interlink(G_cheb, [
    (('G_sqrt', 0), ('G_cheb', 0), None)
])

fn_2 = lambda x : G_id_2.get_qsp_unitary(('G_cheb', 0))({('G_cubic', 0) : x})[0][0]
data = [fn_2(x) for x in tqdm(np.linspace(-1, 1, 200))]
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]

# %%
# IT WORKS!
X = np.linspace(-1, 1, 200)
plt.plot(np.linspace(-1, 1, 200), data)
plt.plot(X, [np.abs(G_cubic.get_qsp_unitary(("G_cubic", 0))({('G_cubic', 0) : x})[0][0]) for x in X])
#plt.plot(X, np.abs(X))

# %%
data
# Out:
# [(0.9999934232593646-0.00362676688301048j),
#  (0.9701477933777544+0.0006878550984037638j),
#  (0.9408911471133756-0.0012955918276878577j),
#  (0.9122250521526025-0.0005293957658316346j),
#  (0.8841451594982612+0.0015503591550666861j),
#  (0.8566466208456699+0.0016265785311989436j),
#  (0.8297250751926127-0.0008694957050172262j),
#  (0.8033758083225979-0.0019252322547158845j),
#  (0.7775928281712292-0.0004168085773967247j),
#  (0.7523698019934606+0.0012030819301673587j),
#  (0.7277011519144098+0.0017783043612997708j),
#  (0.7035818005387409+0.0017906008305814173j),
#  (0.6800061966636727+0.0014402952293107183j),
#  (0.6569676822111674+0.0004901258321790384j),
#  (0.6344586288746915-0.000851796586259841j),
#  (0.6124710878485776-0.0017762171078153336j),
#  (0.5909973978258258-0.001622492608018747j),
#  (0.5700304383158471-0.0005291887794568533j),
#  (0.5495635899760647+0.0007483039610016526j),
#  (0.5295906024735241+0.00155041948720904j),
#  (0.5101054848441307+0.0017681568710501644j),
#  (0.49110242026160017+0.0017090009361563838j),
#  (0.4725756931562469+0.0016782657247454435j),
#  (0.45451963638828424+0.0017081027579029652j),
#  (0.43692859605706125+0.0015873038837984877j),
#  (0.4197969029173697+0.0010782653406837396j),
#  (0.4031188459484175+0.00013616590639149338j),
#  (0.3868886467390698-0.0009968866536790768j),
#  (0.3711004351623827-0.0018633745367197098j),
#  (0.3557482332297503-0.0019937043193700432j),
#  (0.3408259550281181-0.0011537360967145578j),
#  (0.3263274236493024+0.00047608988607693645j),
#  (0.31224640206964843+0.0022878684596182516j),
#  (0.29857663640863874+0.0034385819938553748j),
#  (0.2853119068581662+0.003197063645908021j),
#  (0.4031188459484175+0.00013616590639149338j),
#  (0.4197969029173697+0.0010782653406837396j),
#  (0.43692859605706125+0.0015873038837984877j),
#  (0.4545196363882703+0.0017081027579025961j),
#  (0.4725756931562469+0.0016782657247454435j),
#  (0.49110242026160017+0.0017090009361563838j),
#  (0.5101054848441307+0.0017681568710501644j),
#  (0.5295906024735241+0.00155041948720904j),
#  (0.5495635899760547+0.0007483039610040077j),
#  (0.5700304383158372-0.0005291887794580754j),
#  (0.5909973978258258-0.001622492608018747j),
#  (0.6124710878485776-0.0017762171078153336j),
#  (0.6344586288746915-0.000851796586259841j),
#  (0.6569676822111817+0.000490125832179724j),
#  (0.680006196663673+0.0014402952293110626j),
#  (0.7035818005387409+0.0017906008305814173j),
#  (0.7277011519144098+0.0017783043612997708j),
#  (0.7523698019934606+0.0012030819301673587j),
#  (0.7775928281712244-0.00041680857739685885j),
#  (0.8033758083226032-0.0019252322547161946j),
#  (0.8297250751926127-0.0008694957050172262j),
#  (0.8566466208456699+0.0016265785311989436j),
#  (0.8841451594982612+0.0015503591550666861j),
#  (0.9122250521526017-0.0005293957658328341j),
#  (0.9408911471133748-0.0012955918276887186j),
#  (0.9701477933777544+0.0006878550984037638j),
#  (0.9999934232593646-0.00362676688301048j)]

# %%
# Tests that the arbitrary multiplication gadget works
G_mult = MultiplicationGadget("G_mult")

G_arb_mult = G_sqrt.interlink(G_mult, [
    (('G_sqrt', 0), ('G_mult', 0), None)
])

fn_3 = lambda x, y : (G_arb_mult.get_qsp_unitary(('G_mult', 0))({('G_sqrt', 0) : x, ("G_mult", 1): y}))[0][0]

# %%
data = [[fn_3(x, y) for x in np.linspace(-1, 1, 40)] for y in tqdm(np.linspace(-1, 1, 40))]
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
fn_3(0.71, 0.84)
# Out:
# (0.5960838262618515+0.0015257352470736119j)

# %%
0.71 * 0.84
# Out:
# 0.5963999999999999

# %%
plt.matshow(np.real(data))
plt.colorbar()

# %%
# Plots |x| * y

data_mult = [[np.abs(x) * y for x in np.linspace(-1, 1, 40)] for y in tqdm(np.linspace(-1, 1, 40))]
plt.matshow(np.real(data_mult))
plt.colorbar()
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]

# %%
plt.matshow(np.real(np.array(data) - np.array(data_mult)))
plt.colorbar()

# %%
np.real(np.array(data) - np.array(data_mult))
# Out:
# array([[ 6.57674064e-06,  8.76372487e-06,  2.90453685e-05, ...,  2.90453685e-05,  8.76372487e-06,  6.57674064e-06],
#        [ 6.23947189e-06,  6.15323962e-04,  6.42705704e-04, ..., -5.87593980e-04, -5.98695356e-04,  6.23947189e-06],
#        [ 5.90220314e-06,  8.54935588e-04,  8.84496537e-04, ..., -8.32363825e-04, -8.39205826e-04,  5.90220314e-06],
#        ...,
#        [-5.90220314e-06,  8.39205826e-04,  8.32363825e-04, ..., -8.84496537e-04, -8.54935588e-04, -5.90220314e-06],
#        [-6.23947189e-06,  5.98695356e-04,  5.87593980e-04, ..., -6.42705704e-04, -6.15323962e-04, -6.23947189e-06],
#        [-6.57674064e-06, -8.76372487e-06, -2.90453685e-05, ..., -2.90453685e-05, -8.76372487e-06, -6.57674064e-06]])
