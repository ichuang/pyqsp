# %% [markdown]
# # Testing

# %%
import pyqsp
from pyqsp.gadgets import *
import numpy as np
from matplotlib import pyplot as plt

# %%
L= 6

# First gadget
Xi_1 = np.array([[np.random.uniform() for _ in range(L)], [np.random.uniform() for _ in range(L)]])
S_1 = [[np.random.choice([0, 1]) for _ in range(L-1)], [np.random.choice([0, 1]) for _ in range(L-1)]]

# Second gadget
Xi_2 = np.array([[np.random.uniform() for _ in range(L)], [np.random.uniform() for _ in range(L)]])
S_2 = [[np.random.choice([0, 1]) for _ in range(L-1)], [np.random.choice([0, 1]) for _ in range(L-1)]]

# %%
# Gadgets
G1 = AtomicGadget(Xi_1, S_1, label="G1")
G2 = AtomicGadget(Xi_2, S_1, label="G2")

# %%
# Interlink
G = G1.interlink(G2, [(1, 1)])

# %%
print("In labels = {}".format(G.in_labels))
print("Out labels = {}".format(G.out_labels))
# Out:
# In labels = [('G1', 0), ('G1', 1), ('G2', 0)]
# Out labels = [('G2', 0), ('G2', 1), ('G1', 0)]

# %%
# The new sequence
print(G.get_sequence(('G2', 1)))
# Out:
# ([0.9809046989677872, 0.645501475387214, 0.9474210862412171, 0.8209737952470922, 0.5343824311952021, 1.0856625508543671, 1.4598366347689606, 0.645501475387214, 0.9474210862412171, 0.8209737952470922, 0.5343824311952021, 2.032668687575489, 0.645501475387214, 0.9474210862412171, 0.8209737952470922, 0.5343824311952021, 1.3285707798620492, 0.645501475387214, 0.9474210862412171, 0.8209737952470922, 0.5343824311952021, 0.8811812287876567], [('G1', 1), ('G1', 0), ('G1', 1), ('G1', 1), ('G1', 1), ('G2', 0), ('G1', 1), ('G1', 0), ('G1', 1), ('G1', 1), ('G1', 1), ('G1', 1), ('G1', 0), ('G1', 1), ('G1', 1), ('G1', 1), ('G1', 1), ('G1', 0), ('G1', 1), ('G1', 1), ('G1', 1)])

# %%
f = G.get_qsp_unitary(('G2', 1))

# %%
# QSP polynomial
P = lambda x, y, z : f({('G1', 0): x, ('G1', 1): y, ('G2', 0): z})[0][0]
P_restricted = lambda x, y : P(x, y, 0.5)

# %%
X, Y = np.meshgrid(np.linspace(-1, 1, 100), np.linspace(-1, 1, 100))

# %%
Vals = []
for i in range(len(Y)):
    K = []
    for j in range(len(Y)):
        K.append(P_restricted(X[i][j], Y[i][j]))
    Vals.append(K)

# %%
plt.matshow(np.real(Vals))
plt.colorbar()
